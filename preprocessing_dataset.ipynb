# %%
# importing libraries

import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
# Read the dataset, convert it to DataFrame and display some from it.
df = pd.read_csv("Wuzzuf_Jobs.csv")
df
# Out:
#                                                Title  \
# 0                             Customer Service Agent
# 1                                  Marketing Manager
# 2                  Medical Representative Heliopolis
# 3                          Order Handling Specialist
# 4                                        Storekeeper
# ...                                              ...
# 4375      Corporate Sales Executive - Hotel Supplies
# 4376     Logistics Operations & Warehouse Supervisor
# 4377  English Teacher ( Second Language ) / Lower...
# 4378                         Project Manager - Cairo
# 4379                English Teacher / Primary Stages
#
#                                    Company     Location       Type  \
# 0                         Johnson Controls    New Cairo  Full Time
# 1                    SYE English Community        Dokki  Full Time
# 2                          So Value Pharma        Cairo  Full Time
# 3                         Johnson Controls    New Cairo  Full Time
# 4                             Confidential        Cairo  Full Time
# ...                                    ...          ...        ...
# 4375                                  Term    New Cairo  Full Time
# 4376                     DHL Express Egypt   Abu Rawash  Full Time
# 4377  Modern American School of Egypt 2000    New Cairo  Full Time
# 4378                          KnowledgeNet    Nasr City  Full Time
# 4379  Modern American School of Egypt 2000    New Cairo  Full Time
#
#             Level         YearsExp Country  \
# 0     Entry Level   1-3 Yrs of Exp   Cairo
# 1         Manager  5-10 Yrs of Exp    Giza
# 2     Entry Level   0-5 Yrs of Exp   Egypt
# 3     Experienced   3-5 Yrs of Exp   Cairo
# 4     Experienced    3+ Yrs of Exp   Egypt
# ...           ...              ...     ...
# 4375  Experienced   3-7 Yrs of Exp   Cairo
# 4376      Manager    6+ Yrs of Exp    Giza
# 4377  Experienced   3-7 Yrs of Exp   Cairo
# 4378      Manager    5+ Yrs of Exp   Cairo
# 4379  Experienced   3-7 Yrs of Exp   Cairo
#
#                                                  Skills
# 0     Call Center, Customer Support, Customer Care, ...
# 1     Market Research, Social Media, Online Marketin...
# 2     Cardio-metabolic, Sales Skills, Sales Target, ...
# 3     Supply Officer, Supply Planner, Procurement an...
# 4     Warehousing, Storekeeping, Logistics/Supply Chain
# ...                                                 ...
# 4375  Corporate Sales, Sales Target, English, Comput...
# 4376  Warehousing, Supply Chain Management, Customs ...
# 4377  English Teacher, Lower Primar, Education, Teac...
# 4378  Implementation, Project Management, Informatio...
# 4379  English Teacher, Upper Primary, Education, Tea...
#
# [4380 rows x 8 columns]

# %%
# Display structure and summary of the data.
df.describe()
# Out:
#              Title       Company Location       Type        Level  \
# count         4377          4377     4377       4377         4377
# unique        2965          1534      162          6            9
# top     Accountant  Confidential    Cairo  Full Time  Experienced
# freq            57           590      563       4166         2196
#
#               YearsExp Country  \
# count             4377    4377
# unique             101      42
# top     1-3 Yrs of Exp   Cairo
# freq               414    2227
#
#                                                    Skills
# count                                                4377
# unique                                               4227
# top     Corporate Sales, Real Estate, Advertising, Mar...
# freq                                                   12

# %%
# Clean the data (null, duplications)
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)

# %%
df.head(10)
# Out:
#                                                Title  \
# 0                             Customer Service Agent
# 1                                  Marketing Manager
# 2                  Medical Representative Heliopolis
# 3                          Order Handling Specialist
# 4                                        Storekeeper
# 5        Senior .NET Developer (Desktop Application)
# 6                           Preschool French Teacher
# 7  Junior Business Development Specialist (out door)
# 8                   Indoor Sales Executive Furniture
# 9         Content Creator / Copy Writer - Alexandria
#
#                                              Company     Location       Type  \
# 0                                   Johnson Controls    New Cairo  Full Time
# 1                              SYE English Community        Dokki  Full Time
# 2                                    So Value Pharma        Cairo  Full Time
# 3                                   Johnson Controls    New Cairo  Full Time
# 4                                       Confidential        Cairo  Full Time
# 5                                              Dexef        Maadi  Full Time
# 6                               Leap Development Hub    New Cairo  Full Time
# 7  E3mel Business for Financial & Managerial Cons...        Maadi  Full Time
# 8                                        Line Design    Nasr City  Full Time
# 9                                           EL KHETA   Alexandria  Full Time
#
#          Level         YearsExp Country  \
# 0  Entry Level   1-3 Yrs of Exp   Cairo
# 1      Manager  5-10 Yrs of Exp    Giza
# 2  Entry Level   0-5 Yrs of Exp   Egypt
# 3  Experienced   3-5 Yrs of Exp   Cairo
# 4  Experienced    3+ Yrs of Exp   Egypt
# 5  Experienced   3-5 Yrs of Exp   Cairo
# 6  Entry Level   1-3 Yrs of Exp   Cairo
# 7  Entry Level   1-3 Yrs of Exp   Cairo
# 8  Experienced   1-3 Yrs of Exp   Cairo
# 9  Entry Level    1+ Yrs of Exp   Egypt
#
#                                               Skills
# 0  Call Center, Customer Support, Customer Care, ...
# 1  Market Research, Social Media, Online Marketin...
# 2  Cardio-metabolic, Sales Skills, Sales Target, ...
# 3  Supply Officer, Supply Planner, Procurement an...
# 4  Warehousing, Storekeeping, Logistics/Supply Chain
# 5  ASP.NET, Desktop Development, Information Tech...
# 6                      Education, Education/Teaching
# 7  Sales Target, Sales Skills, B2B Sales, B2C Sal...
# 8                         sales skills, Sales/Retail
# 9  Copywriter, SEO, WordPress, Creative, Writing,...

# %%
df.isna().sum()
# Out:
# Title       0
# Company     0
# Location    0
# Type        0
# Level       0
# YearsExp    0
# Country     0
# Skills      0
# dtype: int64

# %%
# Count the jobs for each company and display that in order 
demanding_companies = pd.DataFrame(df.loc[:,"Company"].value_counts().sort_values(ascending=False))
demanding_companies
# Out:
#                                          Company
# Confidential                                 590
# Mishkat Nour                                  39
# Expand Cart                                   35
# EGIC                                          34
# Aqarmap.com                                   25
# ...                                          ...
# Alkarma Developments                           1
# Egyptian Takaful Property and Liability        1
# Safety Group                                   1
# Genify.ai                                      1
# Next Home                                      1
#
# [1534 rows x 1 columns]

# %%
ax=demanding_companies.head(10).plot.pie(subplots=True, figsize=(8,8))

# %%
# what are the most popular job titles.
popular_job_titles = pd.DataFrame(df.loc[:,"Title"].value_counts())
popular_job_titles
# Out:
#                                    Title
# Accountant                            57
# Sales Representative                  47
# Graphic Designer                      43
# Digital Marketing Specialist          26
# Sales Manager                         25
# ...                                  ...
# Export Documentation Coordinator       1
# Software Quality Control (Tester)      1
# CAD Engineer                           1
# Civil Sales Engineer                   1
# Graphic Design & Media Intern          1
#
# [2965 rows x 1 columns]

# %%
ay=popular_job_titles.head(10).plot.bar()

# %%
popular_areas=pd.DataFrame(df.loc[:,"Country"].value_counts())
popular_areas
# Out:
#                       Country
# Cairo                    2227
# Egypt                     927
# Giza                      776
# Alexandria                129
# Sharqia                    62
# Saudi Arabia               51
# Dakahlia                   37
# Gharbia                    27
# Monufya                    16
# Red Sea                    16
# United Arab Emirates       10
# Suez                        9
# Beheira                     7
# Qalubia                     7
# Damietta                    6
# Assiut                      6
# Fayoum                      6
# Oman                        6
# Matruh                      6
# Beni Suef                   5
# Minya                       5
# El Salvador                 4
# South Sinai                 3
# Brazil                      3
# Kuwait                      2
# India                       2
# Ismailia                    2
# Aswan                       2
# United States               2
# Tunisia                     2
# Qatar                       2
# New Valley                  2
# Qena                        1
# Sri Lanka                   1
# Iraq                        1
# Austria                     1
# Pakistan                    1
# Ukraine                     1
# Philippines                 1
# China                       1
# Indonesia                   1
# Bahrain                     1

# %%
az=popular_areas.head(10).plot.bar()

# %%
# Print skills one by one and how many each repeated and order the output to find out the most important skills required
# we can solve this problem using two ways:
# 1st way:

skills=[]
for skill in df.loc[:,'Skills'].str.split(','):
    skills+=[skill1.strip() for skill1 in skill]

# %%
skills
# Out:
# ['Call Center',
#  'Customer Support',
#  'Customer Care',
#  'English',
#  'Customer Service/Support',
#  'Market Research',
#  'Social Media',
#  'Online Marketing',
#  'Marketing Management',
#  'Marketing Plan',
#  'Event Management',
#  'Education',
#  'FMCG',
#  'Cardio-metabolic',
#  'Sales Skills',
#  'Sales Target',
#  'Customer Service',
#  'Customer Care',
#  'Customer Support',
#  'Pharmacy',
#  'Pharmaceutical',
#  'Science',
#  'Supply Officer',
#  'Supply Planner',
#  'Procurement and Logistics Specialist',
#  'Order Management Specialist',
#  'Order Processing Specialist',
#  'Warehousing',
#  'Storekeeping',
#  'Logistics/Supply Chain',
#  'ASP.NET',
#  'Desktop Development',
#  'Information Technology (IT)',
#  'Devexpress',
#  'MVC',
#  'TFS',
#  'Git',
#  'Computer Science',
#  'WinForms',
#  'MS SQL',
#  'Education',
#  'Education/Teaching',
#  'Sales Target',
#  'Sales Skills',
#  'B2B Sales',
#  'B2C Sales',
#  'Business Development',
#  'CRM',
#  'Marketing',
#  'Corporate Sales',
#  'Business Development',
#  'sales skills',
#  'Sales/Retail',
#  'Copywriter',
#  'SEO',
#  'WordPress',
#  'Creative',
#  'Writing',
#  'Social Media',
#  'Marketing',
#  'Research',
#  'planing',
#  'Blog',
#  'Writing/Editorial',
#  'Education',
#  'Training',
#  'Teaching',
#  'Instructor',
#  'Engineering',
#  'Mechatronics',
#  'Computer Science',
#  'IT Information System',
#  'Training/Instructor',
#  '3 Vacancies',
#  'Males Only',
#  'English Trainer',
#  'Tutor',
#  'Instructor',
#  'Education',
#  'English Teaching',
#  'English Training',
#  'legal',
#  'lawyer',
#  'Legal',
#  'Architecture',
#  'Engineering',
#  'Engineering - Construction/Civil/Architecture',
#  'Human Resources (HR)',
#  'Microsoft Office',
#  'Labor',
#  'English',
#  'Human Resources',
#  'Communication Skills',
#  'Firm',
#  'Administration',
#  'Construction',
#  'Communication Skills',
#  'Purchasing',
#  'Purchasing/Procurement',
#  'Administration',
#  'Office Management',
#  'Communication Skills',
#  'Administration',
#  'Electronics',
#  'Information Technology (IT)',
#  'Business Development',
#  'Product Management',
#  'Sales',
#  'Computer Engineering',
#  'Telecom',
#  'Telecom',
#  'IT',
#  'Computer Science',
#  'Communication',
#  'Maintenance',
#  'Repair',
#  'Office Applications',
#  'Microsoft',
#  'Antivirus',
#  'English',
#  'Safety Management',
#  'Engineering',
#  'Training',
#  'Quality',
#  'Engineering - Other',
#  'Art Directing',
#  'Art Management',
#  'Graphic Design',
#  'Adobe Creative Suite',
#  'Design Software',
#  'Web Development',
#  'Video Production',
#  'Photography',
#  'Office Management',
#  'Admin',
#  'Administration',
#  'Logistics',
#  'Inventory Control',
#  'Purchasing',
#  'Logistics/Supply Chain',
#  'Purchasing/Procurement',
#  'Administration',
#  'Office Management',
#  'Receptionist',
#  'English',
#  'Microsoft Office',
#  'Computer Skills',
#  'Communication',
#  'Administration',
#  'Translation',
#  'Editing',
#  'Education',
#  'English',
#  'Arabic',
#  'Publishing',
#  'Translators',
#  'Languages',
#  'Microsoft Office',
#  'Writing',
#  'lawyer',
#  'Corporate Low',
#  'Legal',
#  'Legal',
#  'Sales Skills',
#  'Customer Service',
#  'Customer Support',
#  'Sales Target',
#  'Account Management',
#  'Customer Service/Support',
#  'CAD',
#  'SolidWorks',
#  'Mechanical Design',
#  'Creative/Design/Art',
#  'Engineering - Mechanical/Electrical',
#  'Information Technology (IT)',
#  'Computer Science',
#  'javaScript',
#  'Software Development',
#  'CSS',
#  'HTML',
#  'React',
#  'Git',
#  'AWS',
#  'UX',
#  'UI',
#  'RESTful',
#  'Industrial Engineering',
#  'Production',
#  'Skills',
#  'Mechanical Engineering',
#  'Manufacturing',
#  'Equipment',
#  'Improvement',
#  'Manufacturing/Production',
#  'Human Resources (HR)',
#  'Personnel',
#  'Interviews',
#  'Selecting',
#  'Mass Hiring',
#  'Microsoft Office',
#  'Training',
#  'English',
#  'Education',
#  'Human Resources',
#  'Computer Science',
#  'Information Technology (IT)',
#  'javaScript',
#  'Software Development',
#  'CSS',
#  'HTML',
#  'Git',
#  'React',
#  'UI',
#  'UX',
#  'AWS',
#  'RESTful',
#  'Software Testing',
#  'Automation Testing',
#  'Information Technology (IT)',
#  'QA',
#  'Agile',
#  'Selenium',
#  'javaScript',
#  'Software Development',
#  'Cloud',
#  'Management',
#  'FMC',
#  'Sales Skills',
#  'Operations',
#  'Logistics/Supply Chain',
#  'Operations/Management',
#  'Sales/Retail',
#  'Business Development',
#  'Architecture',
#  'Engineering',
#  'Presentation Skills',
#  'Negotiation',
#  'Engineering - Construction/Civil/Architecture',
#  'Adobe Photoshop',
#  'Adobe Illustrator',
#  'Editing',
#  'Software',
#  'Creative/Design/Art',
#  'Administration',
#  'HR',
#  'Administration',
#  'Human Resources',
#  'Legal',
#  'Males Only',
#  'Customer Service',
#  'Customer Support',
#  'Customer Care',
#  'Call Center',
#  'Installation',
#  'IT',
#  'Troubleshooting',
#  'Safety',
#  'Quality',
#  'Microsoft Office',
#  'Office Management',
#  'Admin Assistant',
#  'Business Administration',
#  'Accounting',
#  'ERP',
#  'Back Office',
#  'Hotel',
#  'MS Office',
#  'Adobe Illustrator',
#  'Creative',
#  'Art Director',
#  'Visual Design',
#  'After Effects',
#  '3D',
#  'Graphic Design',
#  'Creative/Design/Art',
#  'Education',
#  'Teaching',
#  'Preschool',
#  'English',
#  'Education/Teaching',
#  'Electrical',
#  'Machine Maintenance',
#  'Education',
#  'Training',
#  'Printing Machine',
#  'Installation/Maintenance/Repair',
#  'Customer Service',
#  'Call Center',
#  'Customer Care',
#  'Customer Support',
#  'Customer Service/Support',
#  'Computer Science',
#  'Information Technology (IT)',
#  '.NET',
#  'C#',
#  'SQL',
#  'javaScript',
#  'AJAX',
#  'jQuery',
#  'HTML',
#  'Web APIs',
#  'Angular +2',
#  'Engineering',
#  'Mechanical',
#  'Printing',
#  'Electrical',
#  'Health',
#  'Safety',
#  'Installation/Maintenance/Repair',
#  'Engineering - Mechanical/Electrical',
#  'Graphic Design',
#  'Adobe Illustrator',
#  'Adobe Photoshop',
#  'Branding',
#  'Adobe Indesign',
#  'Marketing',
#  'Adobe After effects',
#  'Infographic Animations',
#  'Sales Skills',
#  'Outdoor Sales',
#  'Sales Target',
#  'Communication Skills',
#  'Corporate Sales',
#  'Presentation Skills',
#  'Selling Skills',
#  'Sales/Retail',
#  'Social Media',
#  'E-marketing',
#  'English',
#  'Photoshop',
#  'Marketing/PR/Advertising',
#  'Media/Journalism/Publishing',
#  'IT Project Management',
#  'Project Planning',
#  'Communication Skills',
#  'Software',
#  'English',
#  'Project Coordination',
#  'Administration',
#  'فنيين',
#  'صيانة',
#  'ميكانيكة',
#  'Manufacturing/Production',
#  '3D Max',
#  'Photoshop',
#  'AutoCAD',
#  'Creative/Design/Art',
#  'Project Management',
#  'HTML',
#  'Software Testing',
#  'Java',
#  'English',
#  'Computer Science',
#  'Software Development',
#  'AWS',
#  'MySQL',
#  'XCode',
#  'Excellent design skills',
#  'upholstery',
#  'Other',
#  'Sales Skills',
#  'Sales Target',
#  'English',
#  'Negotiation',
#  'Sales/Retail',
#  'HVAC',
#  'Mechanical Engineering',
#  'Construction',
#  'Sales Skills',
#  'Sales Target',
#  'Electro Mechanical',
#  'Sales/Retail',
#  'Construction',
#  'Civil Engineering',
#  'Surpac',
#  'Engineering - Construction/Civil/Architecture',
#  'Engineering - Other',
#  'Electronics',
#  'Management',
#  'Lab',
#  'Operations/Management',
#  'Engineering - Mechanical/Electrical',
#  'Communication Skills',
#  'Sales Training',
#  'Sales Skills',
#  'Sales Target',
#  'Presentation Skills',
#  'Instructor',
#  'Sales/Retail',
#  'Training/Instructor',
#  'Sales Skills',
#  'Sales Target',
#  'Sales Manager',
#  'Sales Supervisor',
#  'Communication Skills',
#  'Smart Phones',
#  'English',
#  'Customer Service/Support',
#  'students',
#  'internships',
#  'co teacher',
#  'online teacher assistant',
#  'Education/Teaching',
#  'Rhinoceros',
#  'Autocad',
#  'Developing Design',
#  'Steel',
#  '3ds Max',
#  'Adobe Illustrator',
#  'Adobe Indesign',
#  'Sketching',
#  'Interior Design',
#  'Applied Arts',
#  'Electronics',
#  'Lab',
#  'Purchasing',
#  'Installation',
#  'Operations/Management',
#  'Engineering - Mechanical/Electrical',
#  'students',
#  'internships',
#  'co teacher',
#  'online teacher assistant',
#  'Education/Teaching',
#  'development',
#  'problem',
#  'solving',
#  'R&D/Science',
#  'Analyst/Research',
#  'English',
#  'Microsoft Office',
#  'Mechanical Engineering',
#  'Production Engineering',
#  'Manufacturing/Production',
#  'Engineering - Mechanical/Electrical',
#  'Pharmacy',
#  'Science',
#  'Sales Skills',
#  'Vet',
#  'Medical Sales',
#  'Medical/Healthcare',
#  'Sales/Retail',
#  'Pharmaceutical',
#  'Customer Care',
#  'Customer Support',
#  'Sales',
#  'Communication',
#  'Computer',
#  'Customer Service/Support',
#  'Marketing/PR/Advertising',
#  'Sales/Retail',
#  'Logistics',
#  'Retail',
#  'menswear',
#  'Logistics/Supply Chain',
#  'Project/Program Management',
#  'Sales/Retail',
#  'Microsoft Office',
#  'Computer Science',
#  'Computer Engineering',
#  'Networking',
#  'Project Management',
#  'DMS Project Manager',
#  'English',
#  'Help Desk',
#  'IT',
#  'IT/Software Development',
#  'development',
#  'problem',
#  'solving',
#  'language',
#  '· R&D/Science',
#  'Analyst/Research',
#  'Curriculum Development',
#  'Education',
#  'Teaching',
#  'SME',
#  'Science',
#  'Biology',
#  'Chemistry',
#  'Engineering',
#  'Physics',
#  'Teacher',
#  'Writing',
#  'Computer Skills',
#  'English',
#  'Communication',
#  'Accounting',
#  'SAP',
#  'Finance',
#  'Financial Analysis',
#  'Financial Management',
#  'Accounting/Finance',
#  'Strategy',
#  'Market Research',
#  'Pharmacy',
#  'Pharmaceutical',
#  'Physician',
#  'Physics',
#  'Medical',
#  'Social Media',
#  'relationship',
#  'Negotiation',
#  'أخصائي نفسي',
#  'اخصائي نفسي',
#  'Medical/Healthcare',
#  'Other',
#  'Real Estate',
#  'Sales Skills',
#  'Sales Target',
#  'Customer Service',
#  'Sales/Retail',
#  'Real Estate',
#  'Sales Skills',
#  'Sales Target',
#  'Customer Service',
#  'Sales/Retail',
#  'Sales Skills',
#  'Sales Target',
#  'Customer Service',
#  'Customer Service/Support',
#  'Sales/Retail',
#  'اخصائي اجتماعي',
#  'Medical/Healthcare',
#  'Other',
#  'Real Estate',
#  'Sales Skills',
#  'Sales Target',
#  'Customer Service',
#  'Sales/Retail',
#  'Networking',
#  'Computer Science',
#  'Engineering',
#  'ITIL Foundation',
#  'Security',
#  'CCNP',
#  'Communication',
#  'English',
#  'Installation',
#  'Office Management',
#  'Secretary',
#  'Microsoft Office',
#  'Administration',
#  'Females Only',
#  'Sales Team Leader',
#  'Real Estate',
#  'Sales Target',
#  'Sales Skills',
#  'Communication Skills',
#  'Presentation Skills',
#  'Management',
#  'Training',
#  'Social Media',
#  'E-marketing',
#  'Communication',
#  'Management',
#  'Logistics',
#  'Web Merchandising',
#  'Financial Analysis',
#  'Market Research',
#  'Sales/Retail',
#  'Supervisor',
#  'OPPO',
#  'Sales Skills',
#  'Sales Target',
#  'Customer Service',
#  'English',
#  'Sales/Retail',
#  'Finance',
#  'Accounting Software',
#  'Computer Skills',
#  'Financial Analysis',
#  'Retail',
#  'Accounting/Finance',
#  'SEM',
#  'Digital',
#  'Advertising',
#  'PPC',
#  'Marketing Campaigns',
#  'ROI',
#  'Social Media',
#  'SEO Strategy',
#  'Marketing/PR/Advertising',
#  'Computer Science',
#  'Sales Skills',
#  'Sales Target',
#  'IT Sales',
#  'Engineering',
#  'Telecom',
#  'IT/Software Development',
#  'Sales/Retail',
#  'Software Engineering',
#  'Computer Science',
#  'Software Development',
#  'C++',
#  'Python',
#  'Java',
#  'Coding',
#  'Internship',
#  'Programming',
#  'Customer Service',
#  'Communication',
#  'Industrial Automation',
#  'Sales Management',
#  'Sales Skills',
#  'Sales Target',
#  'Business Development',
#  'Sales/Retail',
#  'Supply Chain',
#  'Warehousing',
#  'Operations',
#  'Logistics/Supply Chain',
#  'Operations/Management',
#  'Mobile Applications',
#  'Information Technology (IT)',
#  'Computer Science',
#  'Software Development',
#  'Engineering',
#  'Telecom',
#  'IT/Software Development',
#  'Business Development',
#  'Marketing',
#  'Sales Skills',
#  'Customer Service',
#  'Programming',
#  'Business Development',
#  'Marketing/PR/Advertising',
#  'Computer Engineering',
#  'Information Technology (IT)',
#  'Software Development',
#  'Docker',
#  'AWS',
#  'Linux',
#  'MySQL',
#  'Java',
#  'MongoDB',
#  'Azure',
#  'Logistics',
#  'Supply Chain',
#  'Procurement',
#  'English',
#  'AutoCAD',
#  'Logistics/Supply Chain',
#  'Females Only',
#  'Sales Skills',
#  'Real Estate',
#  'Communication',
#  'Negotiation',
#  'Selling',
#  'Sales Target',
#  'Business Development',
#  'Sales/Retail',
#  'Business Development',
#  'Marketing',
#  'Sales Skills',
#  'Business Development',
#  'Marketing/PR/Advertising',
#  'engineering',
#  'google',
#  'technologu',
#  'java',
#  'python',
#  'C++',
#  'developer',
#  'internship',
#  'IT/Software Development',
#  'Software Testing',
#  'Agile',
#  'ISTQB',
#  'Computer Science',
#  'Information Technology (IT)',
#  'Scrum',
#  'E-commerce',
#  'Web Testing',
#  'SQL',
#  'Quality',
#  'Finance',
#  'Financial Management',
#  'Financial Analysis',
#  'Accounting/Finance',
#  'Administration',
#  'Office Management',
#  'Microsoft Office',
#  'Secretary',
#  'Administration',
#  'Sales Skills',
#  'Construction',
#  'AutoCAD',
#  'Microsoft Office',
#  'Civil Engineering',
#  'Mechanical Engineering',
#  'Sales/Retail',
#  'Social Media',
#  'Content Writing',
#  'Content Creation',
#  'Content Development',
#  'Editorial',
#  'Advertising',
#  'Facebook',
#  'Instagram',
#  'Youtube',
#  'Maintenance',
#  'Computer Skills',
#  'Mechanical Engineering',
#  'Installation/Maintenance/Repair',
#  'Engineering - Mechanical/Electrical',
#  'Jenkins',
#  'CI/CD',
#  'Docker',
#  'Nginx',
#  'Information Technology (IT)',
#  'MySQL',
#  'Git',
#  'Apache',
#  'IT/Software Development',
#  'Males Preferred',
#  'Corporate Lawyer',
#  'Legal',
#  'Legal',
#  'Mobile Application',
#  'Information Technology (IT)',
#  'Computer Science',
#  'Telecom Engineering',
#  'Software Development',
#  'IT/Software Development',
#  'Social Media',
#  'Real Estate',
#  'Google Ads',
#  'E-marketing',
#  'Content Creation',
#  'Lead Generation',
#  'Marketing/PR/Advertising',
#  'Technical Office',
#  'Engineering',
#  'Computer Skills',
#  'Mechanical',
#  'SAP',
#  'Engineering - Mechanical/Electrical',
#  'Sales Target',
#  'Furniture Sales',
#  'Furniture Design',
#  'Customer Service',
#  'Arabic',
#  'English',
#  'Wood',
#  'Customer Service/Support',
#  'Sales/Retail',
#  'Logistics',
#  'Supply Chain',
#  'Warehouse Keepering',
#  'Logistics/Supply Chain',
#  'Females Preferred',
#  'Telesales Representative',
#  'Customer Service',
#  'Customer Support',
#  'Customer Care',
#  'Sales Skills',
#  'Sales Target',
#  'Sales/Retail',
#  'Design',
#  'Construction',
#  'Mechanical Engineering',
#  'Electrical Engineering',
#  'MEP',
#  'Engineering - Mechanical/Electrical',
#  'Concrete',
#  'Constructions',
#  'Six Sigma',
#  'Engineering - Construction/Civil/Architecture',
#  'Graphic Design',
#  'Social Media',
#  'Advertising',
#  'Creative/Design/Art',
#  'Marketing/PR/Advertising',
#  'Customer Service',
#  'Computer Science',
#  'Sales Skills',
#  'Sales Target',
#  'English',
#  'Computer Skills',
#  'Microsoft Office',
#  'Sales/Retail',
#  'Software Development',
#  'ASP.NET',
#  'Web Development',
#  'javaScript',
#  'CSS',
#  'AJAX',
#  'T-SQL',
#  'SharePoint 2016/2013/2010',
#  'Html 4',
#  'Maintenance',
#  'Civil Engineering',
#  'Customer Service',
#  'Engineering - Construction/Civil/Architecture',
#  'Installation/Maintenance/Repair',
#  'Maintenance',
#  'Mechanical Engineering',
#  'Technical',
#  'English',
#  'Installation/Maintenance/Repair',
#  'Engineering - Mechanical/Electrical',
#  'Online Sales',
#  'E-Commerce',
#  'Retail',
#  'Marketing',
#  'English',
#  'Sales Skills',
#  'Menswear',
#  'Customer Service/Support',
#  'Sales/Retail',
#  'Fashion',
#  'Software Development',
#  'Front End',
#  'UI/UX',
#  'UX',
#  'iOS',
#  'Android',
#  'UI',
#  'Computer Science',
#  'IT/Software Development',
#  'UI/UX Design',
#  'UI Design',
#  'Photoshop',
#  'Creative/Design/Art',
#  'IT/Software Development',
#  'ERP',
#  'Information Technology (IT)',
#  'Odoo Modules',
#  'Computer Science',
#  'Application Manager',
#  'IT/Software Development',
#  'Project/Program Management',
#  'Teaching',
#  'English',
#  'Communication Skills',
#  'Training',
#  'Education',
#  'R&D/Science',
#  'Education/Teaching',
#  'Sales Skills',
#  'Sales Target',
#  'Customer Service',
#  'Healthcare',
#  'Gym',
#  'Sports',
#  'Leisure',
#  'English',
#  'Sales/Retail',
#  'Sports and Leisure',
#  'Information Technology (IT)',
#  'javaScript',
#  'jQuery',
#  'HTML',
#  'CSS',
#  'Angular',
#  'Bootstrap',
#  'Computer Science',
#  'Software Development',
#  'Curriculum',
#  'Teaching',
#  'Maths',
#  'Education',
#  'Education/Teaching',
#  'Computer Science',
#  'Software Development',
#  'Software Engineering',
#  'HTML',
#  'Information Technology (IT)',
#  'PHP',
#  'MySQL',
#  'Java',
#  'AWS',
#  'APIs',
#  'Computer Science',
#  'Information Technology (IT)',
#  'Civil Engineering',
#  'Engineering - Construction/Civil/Architecture',
#  'Engineering - Telecom/Technology',
#  'Supply Chain',
#  'Purchasing',
#  'Logistics',
#  'English',
#  'Export',
#  'Import',
#  'Microsoft Office',
#  'Computer Skills',
#  'Microsoft Excel',
#  'Management',
#  'Cloud',
#  'Linux',
#  'AWS',
#  'CCNA',
#  'RHCE',
#  'IT',
#  'Computer Science',
#  'Development',
#  'Networking',
#  'Troubleshooting',
#  'IT/Software Development',
#  'Linux',
#  'Technical Support',
#  'CCNA',
#  'Information Technology (IT)',
#  'Computer Science',
#  'Networking',
#  'Engineering',
#  'SS7',
#  'GSM',
#  'Troubleshoot',
#  'Infection Control',
#  'Healthcare',
#  'Medicine',
#  'Pharmacy',
#  'Dentistry',
#  'Medical/Healthcare',
#  'Adobe Photoshop',
#  'Adobe Illustrator',
#  'InDesign',
#  'Communication',
#  'Design Software',
#  'Technologies',
#  'Creative/Design/Art',
#  'Python',
#  'Odoo Modules',
#  'Design',
#  'APIs',
#  'Computer Science',
#  'Information Technology (IT)',
#  'IT/Software Development',
#  'Engineering - Telecom/Technology',
#  'Indoor Sales',
#  'Outdoor Sales',
#  'FMCG',
#  'Sales Target',
#  'Sales/Retail',
#  'DevOps',
#  'Gitlab',
#  'Jenkins',
#  'Docker',
#  'Kubernetes',
#  'DHCP',
#  'DNS',
#  'SSL',
#  'TCP',
#  'UDP',
#  'Information Technology (IT)',
#  'Microsoft Server',
#  'Tomcat',
#  'Administration',
#  'Microsoft Office',
#  'Typing Skills',
#  'Content',
#  'Administration',
#  'Writing/Editorial',
#  'Adobe Photoshop',
#  'Adobe Illustrator',
#  'Communication Skills',
#  'Management',
#  'Arabic',
#  'After Effect',
#  'Creative/Design/Art',
#  'Warehousing',
#  'Inventory Control',
#  'Supply Chain Management',
#  'Medical',
#  'Pharmacy',
#  'Medicine',
#  'Material Planning',
#  'Suppliers',
#  'Doctor',
#  'Operations',
#  'Sales Skills',
#  'Business Development',
#  'Food Delivery',
#  'Presentation Skills',
#  'English',
#  'Sales/Retail',
#  'Males Preferred',
#  'Mechatronics',
#  'Electrical',
#  'Electronics',
#  '3D Printing',
#  'SolidWorks',
#  '3D',
#  'Engineering',
#  'Engineering - Mechanical/Electrical',
#  '2 Vacancies',
#  'Sales Skills',
#  'Sales Target',
#  'Business Development',
#  'Selling',
#  'Product',
#  'Business Opportunities',
#  'Business Development',
#  'Mechatronics Engineering',
#  'Biomedical Engineering',
#  'FDM 3d printers',
#  'Arabic',
#  'English',
#  ...]

# %%
skills_dic={}
for skill in skills:
    skills_dic[skill]=skills_dic.get(skill,0)+1

# %%
skills_dic
# Out:
# {'Call Center': 97,
#  'Customer Support': 347,
#  'Customer Care': 337,
#  'English': 1269,
#  'Customer Service/Support': 287,
#  'Market Research': 73,
#  'Social Media': 260,
#  'Online Marketing': 53,
#  'Marketing Management': 6,
#  'Marketing Plan': 3,
#  'Event Management': 2,
#  'Education': 110,
#  'FMCG': 56,
#  'Cardio-metabolic': 1,
#  'Sales Skills': 776,
#  'Sales Target': 705,
#  'Customer Service': 573,
#  'Pharmacy': 83,
#  'Pharmaceutical': 120,
#  'Science': 73,
#  'Supply Officer': 1,
#  'Supply Planner': 1,
#  'Procurement and Logistics Specialist': 1,
#  'Order Management Specialist': 1,
#  'Order Processing Specialist': 1,
#  'Warehousing': 34,
#  'Storekeeping': 5,
#  'Logistics/Supply Chain': 167,
#  'ASP.NET': 42,
#  'Desktop Development': 1,
#  'Information Technology (IT)': 577,
#  'Devexpress': 1,
#  'MVC': 58,
#  'TFS': 19,
#  'Git': 76,
#  'Computer Science': 690,
#  'WinForms': 2,
#  'MS SQL': 3,
#  'Education/Teaching': 105,
#  'B2B Sales': 22,
#  'B2C Sales': 1,
#  'Business Development': 251,
#  'CRM': 66,
#  'Marketing': 206,
#  'Corporate Sales': 42,
#  'sales skills': 3,
#  'Sales/Retail': 655,
#  'Copywriter': 5,
#  'SEO': 104,
#  'WordPress': 18,
#  'Creative': 57,
#  'Writing': 76,
#  'Research': 27,
#  'planing': 1,
#  'Blog': 2,
#  'Writing/Editorial': 68,
#  'Training': 82,
#  'Teaching': 71,
#  'Instructor': 18,
#  'Engineering': 238,
#  'Mechatronics': 14,
#  'IT Information System': 1,
#  'Training/Instructor': 58,
#  '3 Vacancies': 24,
#  'Males Only': 99,
#  'English Trainer': 1,
#  'Tutor': 1,
#  'English Teaching': 8,
#  'English Training': 1,
#  'legal': 2,
#  'lawyer': 2,
#  'Legal': 47,
#  'Architecture': 75,
#  'Engineering - Construction/Civil/Architecture': 121,
#  'Human Resources (HR)': 97,
#  'Microsoft Office': 580,
#  'Labor': 3,
#  'Human Resources': 148,
#  'Communication Skills': 454,
#  'Firm': 1,
#  'Administration': 537,
#  'Construction': 117,
#  'Purchasing': 58,
#  'Purchasing/Procurement': 47,
#  'Office Management': 179,
#  'Electronics': 23,
#  'Product Management': 13,
#  'Sales': 95,
#  'Computer Engineering': 147,
#  'Telecom': 28,
#  'IT': 71,
#  'Communication': 235,
#  'Maintenance': 88,
#  'Repair': 16,
#  'Office Applications': 1,
#  'Microsoft': 5,
#  'Antivirus': 1,
#  'Safety Management': 1,
#  'Quality': 127,
#  'Engineering - Other': 51,
#  'Art Directing': 1,
#  'Art Management': 1,
#  'Graphic Design': 75,
#  'Adobe Creative Suite': 9,
#  'Design Software': 4,
#  'Web Development': 55,
#  'Video Production': 3,
#  'Photography': 11,
#  'Admin': 6,
#  'Logistics': 191,
#  'Inventory Control': 8,
#  'Receptionist': 19,
#  'Computer Skills': 233,
#  'Translation': 19,
#  'Editing': 46,
#  'Arabic': 158,
#  'Publishing': 7,
#  'Translators': 1,
#  'Languages': 6,
#  'Corporate Low': 1,
#  'Account Management': 38,
#  'CAD': 12,
#  'SolidWorks': 9,
#  'Mechanical Design': 3,
#  'Creative/Design/Art': 186,
#  'Engineering - Mechanical/Electrical': 95,
#  'javaScript': 174,
#  'Software Development': 363,
#  'CSS': 109,
#  'HTML': 105,
#  'React': 26,
#  'AWS': 40,
#  'UX': 48,
#  'UI': 65,
#  'RESTful': 25,
#  'Industrial Engineering': 4,
#  'Production': 54,
#  'Skills': 21,
#  'Mechanical Engineering': 127,
#  'Manufacturing': 76,
#  'Equipment': 2,
#  'Improvement': 1,
#  'Manufacturing/Production': 64,
#  'Personnel': 76,
#  'Interviews': 3,
#  'Selecting': 7,
#  'Mass Hiring': 3,
#  'Software Testing': 32,
#  'Automation Testing': 5,
#  'QA': 51,
#  'Agile': 106,
#  'Selenium': 7,
#  'Cloud': 12,
#  'Management': 194,
#  'FMC': 1,
#  'Operations': 104,
#  'Operations/Management': 215,
#  'Presentation Skills': 43,
#  'Negotiation': 70,
#  'Adobe Photoshop': 129,
#  'Adobe Illustrator': 118,
#  'Software': 65,
#  'HR': 97,
#  'Installation': 73,
#  'Troubleshooting': 41,
#  'Safety': 18,
#  'Admin Assistant': 11,
#  'Business Administration': 182,
#  'Accounting': 208,
#  'ERP': 99,
#  'Back Office': 5,
#  'Hotel': 3,
#  'MS Office': 156,
#  'Art Director': 1,
#  'Visual Design': 2,
#  'After Effects': 12,
#  '3D': 26,
#  'Preschool': 1,
#  'Electrical': 16,
#  'Machine Maintenance': 1,
#  'Printing Machine': 1,
#  'Installation/Maintenance/Repair': 71,
#  '.NET': 25,
#  'C#': 67,
#  'SQL': 103,
#  'AJAX': 20,
#  'jQuery': 78,
#  'Web APIs': 1,
#  'Angular +2': 1,
#  'Mechanical': 20,
#  'Printing': 7,
#  'Health': 3,
#  'Branding': 18,
#  'Adobe Indesign': 19,
#  'Adobe After effects': 1,
#  'Infographic Animations': 1,
#  'Outdoor Sales': 90,
#  'Selling Skills': 17,
#  'E-marketing': 167,
#  'Photoshop': 35,
#  'Marketing/PR/Advertising': 265,
#  'Media/Journalism/Publishing': 125,
#  'IT Project Management': 1,
#  'Project Planning': 2,
#  'Project Coordination': 7,
#  'فنيين': 1,
#  'صيانة': 1,
#  'ميكانيكة': 1,
#  '3D Max': 13,
#  'AutoCAD': 116,
#  'Project Management': 115,
#  'Java': 41,
#  'MySQL': 66,
#  'XCode': 2,
#  'Excellent design skills': 1,
#  'upholstery': 1,
#  'Other': 13,
#  'HVAC': 20,
#  'Electro Mechanical': 1,
#  'Civil Engineering': 79,
#  'Surpac': 1,
#  'Lab': 3,
#  'Sales Training': 2,
#  'Sales Manager': 4,
#  'Sales Supervisor': 3,
#  'Smart Phones': 2,
#  'students': 2,
#  'internships': 2,
#  'co teacher': 2,
#  'online teacher assistant': 2,
#  'Rhinoceros': 1,
#  'Autocad': 1,
#  'Developing Design': 1,
#  'Steel': 2,
#  '3ds Max': 13,
#  'Sketching': 1,
#  'Interior Design': 24,
#  'Applied Arts': 30,
#  'development': 2,
#  'problem': 2,
#  'solving': 2,
#  'R&D/Science': 65,
#  'Analyst/Research': 35,
#  'Production Engineering': 8,
#  'Vet': 7,
#  'Medical Sales': 18,
#  'Medical/Healthcare': 96,
#  'Computer': 11,
#  'Retail': 101,
#  'menswear': 1,
#  'Project/Program Management': 50,
#  'Networking': 31,
#  'DMS Project Manager': 1,
#  'Help Desk': 19,
#  'IT/Software Development': 191,
#  'language': 1,
#  '· R&D/Science': 1,
#  'Curriculum Development': 2,
#  'SME': 1,
#  'Biology': 3,
#  'Chemistry': 19,
#  'Physics': 3,
#  'Teacher': 6,
#  'SAP': 51,
#  'Finance': 300,
#  'Financial Analysis': 277,
#  'Financial Management': 174,
#  'Accounting/Finance': 303,
#  'Strategy': 5,
#  'Physician': 2,
#  'Medical': 78,
#  'relationship': 1,
#  'أخصائي نفسي': 1,
#  'اخصائي نفسي': 1,
#  'Real Estate': 173,
#  'اخصائي اجتماعي': 1,
#  'ITIL Foundation': 1,
#  'Security': 20,
#  'CCNP': 10,
#  'Secretary': 104,
#  'Females Only': 60,
#  'Sales Team Leader': 1,
#  'Web Merchandising': 2,
#  'Supervisor': 3,
#  'OPPO': 1,
#  'Accounting Software': 26,
#  'SEM': 25,
#  'Digital': 8,
#  'Advertising': 109,
#  'PPC': 11,
#  'Marketing Campaigns': 24,
#  'ROI': 7,
#  'SEO Strategy': 1,
#  'IT Sales': 12,
#  'Software Engineering': 152,
#  'C++': 22,
#  'Python': 32,
#  'Coding': 4,
#  'Internship': 2,
#  'Programming': 51,
#  'Industrial Automation': 2,
#  'Sales Management': 17,
#  'Supply Chain': 159,
#  'Mobile Applications': 7,
#  'Docker': 13,
#  'Linux': 40,
#  'MongoDB': 16,
#  'Azure': 14,
#  'Procurement': 74,
#  'Selling': 30,
#  'engineering': 3,
#  'google': 3,
#  'technologu': 1,
#  'java': 3,
#  'python': 1,
#  'developer': 1,
#  'internship': 2,
#  'ISTQB': 9,
#  'Scrum': 29,
#  'E-commerce': 17,
#  'Web Testing': 1,
#  'Content Writing': 21,
#  'Content Creation': 19,
#  'Content Development': 2,
#  'Editorial': 4,
#  'Facebook': 22,
#  'Instagram': 6,
#  'Youtube': 4,
#  'Jenkins': 7,
#  'CI/CD': 4,
#  'Nginx': 2,
#  'Apache': 4,
#  'Males Preferred': 31,
#  'Corporate Lawyer': 1,
#  'Mobile Application': 7,
#  'Telecom Engineering': 16,
#  'Google Ads': 11,
#  'Lead Generation': 13,
#  'Technical Office': 28,
#  'Furniture Sales': 4,
#  'Furniture Design': 1,
#  'Wood': 6,
#  'Warehouse Keepering': 1,
#  'Females Preferred': 24,
#  'Telesales Representative': 1,
#  'Design': 123,
#  'Electrical Engineering': 93,
#  'MEP': 9,
#  'Concrete': 2,
#  'Constructions': 2,
#  'Six Sigma': 10,
#  'T-SQL': 3,
#  'SharePoint 2016/2013/2010': 1,
#  'Html 4': 1,
#  'Technical': 15,
#  'Online Sales': 12,
#  'E-Commerce': 30,
#  'Menswear': 2,
#  'Fashion': 50,
#  'Front End': 15,
#  'UI/UX': 12,
#  'iOS': 33,
#  'Android': 27,
#  'UI/UX Design': 3,
#  'UI Design': 5,
#  'Odoo Modules': 4,
#  'Application Manager': 1,
#  'Healthcare': 35,
#  'Gym': 3,
#  'Sports': 4,
#  'Leisure': 1,
#  'Sports and Leisure': 6,
#  'Angular': 54,
#  'Bootstrap': 20,
#  'Curriculum': 1,
#  'Maths': 4,
#  'PHP': 70,
#  'APIs': 30,
#  'Engineering - Telecom/Technology': 34,
#  'Export': 17,
#  'Import': 11,
#  'Microsoft Excel': 69,
#  'CCNA': 31,
#  'RHCE': 2,
#  'Development': 21,
#  'Technical Support': 47,
#  'SS7': 1,
#  'GSM': 1,
#  'Troubleshoot': 1,
#  'Infection Control': 2,
#  'Medicine': 29,
#  'Dentistry': 6,
#  'InDesign': 20,
#  'Technologies': 1,
#  'Indoor Sales': 48,
#  'DevOps': 15,
#  'Gitlab': 2,
#  'Kubernetes': 5,
#  'DHCP': 3,
#  'DNS': 8,
#  'SSL': 1,
#  'TCP': 1,
#  'UDP': 1,
#  'Microsoft Server': 1,
#  'Tomcat': 4,
#  'Typing Skills': 3,
#  'Content': 38,
#  'After Effect': 4,
#  'Supply Chain Management': 11,
#  'Material Planning': 3,
#  'Suppliers': 3,
#  'Doctor': 3,
#  'Food Delivery': 1,
#  '3D Printing': 1,
#  '2 Vacancies': 42,
#  'Product': 10,
#  'Business Opportunities': 1,
#  'Mechatronics Engineering': 2,
#  'Biomedical Engineering': 5,
#  'FDM 3d printers': 1,
#  'SLA 3D Printers': 1,
#  'Digital Marketing': 154,
#  'Business': 71,
#  'Writing Skills': 5,
#  'Creativity': 6,
#  'Mobile Development': 22,
#  'Flutter Mobile Application': 1,
#  'GraphQL': 6,
#  'Labor Law': 30,
#  'Spreadsheets': 2,
#  'Telecommunication': 26,
#  'Telesales': 76,
#  'System Analysis': 10,
#  'Business Analysis': 26,
#  'CBAP': 2,
#  'CCBA': 2,
#  'Factory': 6,
#  'General Manager': 2,
#  'C-Level Executive/GM/Director': 3,
#  'Research & Development': 4,
#  'R&D': 14,
#  'Minesweeper': 1,
#  'Robocon': 2,
#  'ROV': 1,
#  'Formula': 1,
#  'Electrical Power': 6,
#  'Irrigation': 1,
#  'Landscape Designing': 1,
#  'Site Engineering': 9,
#  'Agriculture': 33,
#  'Housekeeping': 2,
#  'Hospitality': 16,
#  'Hospitality/Hotels/Food Services': 7,
#  'Structural Engineering': 2,
#  'Civil': 11,
#  'Facility': 2,
#  'Fleet Management': 4,
#  'Power Engineering': 4,
#  'Auto CAD': 7,
#  '2D Drawings': 2,
#  'iOS Development': 2,
#  'React Native': 13,
#  'Marketing Agencies': 1,
#  'Implementation': 10,
#  'Technical Analysis': 4,
#  'Data Entry': 18,
#  'Speed': 1,
#  'Leadership Skills': 6,
#  'Drawing': 7,
#  'Office Furniture': 3,
#  'technical': 1,
#  'SOLUTIONS': 1,
#  'Word': 11,
#  'Social Media Management': 4,
#  'AX': 7,
#  'Microsoft Dynamics AX': 5,
#  'Dynamics AX 2012': 1,
#  'SSRS': 4,
#  'msca': 1,
#  'VDI': 1,
#  'Mechanics': 2,
#  'Maintenance Equipment': 1,
#  'Heavy Equipment': 3,
#  'Equipment Maintenance': 1,
#  'Warehouse': 10,
#  'Admin Work': 10,
#  'Recruitment': 118,
#  'Performance Management': 11,
#  'Employee Relations': 10,
#  'Compensation': 4,
#  'Benefits': 2,
#  'Typing': 9,
#  'Excel': 85,
#  'Organizational Development': 4,
#  'Infrastructure Engineering': 2,
#  'Microsoft SQL Server': 11,
#  'Microsoft Nav Development': 1,
#  'Web API': 7,
#  'GITHub': 1,
#  'Warehouse Accountant': 2,
#  'Commerce': 154,
#  'Microsoft Dynamics': 5,
#  'Real Estate Sales': 23,
#  'Property Consultant': 11,
#  'Shop Drawings': 10,
#  'Site': 10,
#  'Dutch': 3,
#  'Sales Engineering': 17,
#  'Agriculture Software': 1,
#  'PIVOT Farming': 1,
#  'Palm Tree Farming': 1,
#  'SAAS': 1,
#  'Front Desk': 10,
#  'Architectural': 4,
#  'Data Analysis': 13,
#  'SOP': 2,
#  'Pharmaceutical Processes': 1,
#  'French': 30,
#  'Property': 38,
#  'OOP': 35,
#  'SharePoint': 11,
#  'Cost Accounting': 13,
#  'Mobile Hardware': 1,
#  'Mobile Repair': 1,
#  'Mobile Maintenance': 1,
#  'Planning': 58,
#  'Product Development': 4,
#  'CX': 1,
#  'Brokerage': 27,
#  'Team Leader': 3,
#  'Sales Executive': 6,
#  'Coldwell Banker': 1,
#  'Social media management': 1,
#  'GCC': 1,
#  'Media Buying': 10,
#  'MacOS': 1,
#  'Auditing': 31,
#  'site': 1,
#  'Mechanical Engineer': 1,
#  'Back End': 7,
#  'Backend Development': 1,
#  'MV': 2,
#  'HTML5': 78,
#  'CSS3': 55,
#  'RWD': 1,
#  'AngularJS': 9,
#  'API': 10,
#  'NG2': 1,
#  'NODEJS': 1,
#  'Mobile Design': 1,
#  'Adobe Suite': 7,
#  'Mock-Ups': 1,
#  'Mobile Interface': 1,
#  'Data Quality': 1,
#  'Financial': 3,
#  'Quality Assurance': 73,
#  'Quality Control': 72,
#  'Insurance': 44,
#  'procuremn': 1,
#  'Leadership': 54,
#  'Angular.JS': 1,
#  'Node.JS': 3,
#  'Mongo DB': 2,
#  'Visio': 5,
#  'Oracle BPM': 1,
#  'Aris': 1,
#  'Testing': 30,
#  'Spring Stack': 1,
#  'Technical Writing': 5,
#  'Documentation': 7,
#  'SDKs': 1,
#  'Analyst': 4,
#  'Database': 11,
#  'Android Development': 3,
#  'IT HelpDesk': 1,
#  'Networks': 13,
#  'NAV': 1,
#  'Instructional Design': 3,
#  'Educational Content': 2,
#  'Educational Script': 1,
#  'Educational Programs Design': 1,
#  'Distance Learning Systems': 1,
#  'Web Design': 24,
#  'Social Media Campaigns': 3,
#  'Analysis': 31,
#  'Data Mining': 3,
#  'Economics': 15,
#  'Line Manager': 1,
#  'CORE .Net': 1,
#  'Production Planning': 4,
#  'MRP': 5,
#  'Manufacturing Resource Planning': 2,
#  'QC': 36,
#  'Raw Material Recruitments': 1,
#  'Health and Safety': 3,
#  'Statistical Analysis': 1,
#  'Furniture': 27,
#  'Google Analytics': 40,
#  'Dynamic Ads': 2,
#  'Reviewing': 2,
#  'Facebook Ads': 4,
#  'Financial Reports': 6,
#  'Vendors': 4,
#  'Cost': 6,
#  'APICS': 1,
#  'Forcasting': 2,
#  'Microsoft Windows': 2,
#  'CPT': 1,
#  'Channel Sales': 1,
#  'Digital Media': 23,
#  'Video Editing': 14,
#  'Photographing': 2,
#  'Art Production': 1,
#  'InDesign CC': 1,
#  'Photoshop CC': 1,
#  'Illustrator CC': 1,
#  'Food Industry': 10,
#  'Food Science': 2,
#  'Food Safety': 2,
#  'Quality Supervising': 1,
#  'HRIS': 6,
#  'Administrative': 11,
#  'Interviewing': 25,
#  'HR Management': 5,
#  'Adobe After Effects': 16,
#  'Adobe Premiere': 12,
#  'Editing Software': 3,
#  'Motion Graphics': 8,
#  'Marketing Strategy': 5,
#  'Social Media Strategy': 1,
#  'Offline Marketing': 1,
#  'Internal Audit': 7,
#  'e-learning': 1,
#  'Digital Transformations': 1,
#  'JavaScript': 17,
#  'ChartJS': 1,
#  'SCSS': 3,
#  'Angular5+': 1,
#  'SASS': 13,
#  'Front-End': 28,
#  'REST APIs': 3,
#  'Slack': 1,
#  'Trello': 2,
#  'Jira': 14,
#  'VueJs': 1,
#  'Educational Technology': 1,
#  'eLearning': 1,
#  'BACKEND': 1,
#  'FULL STACK': 1,
#  'DEVELOPER': 1,
#  'JQUERY': 1,
#  'Process': 2,
#  'CFA': 5,
#  'Financial Statements': 6,
#  'GAAP': 8,
#  'Credit Data Analysis': 1,
#  'Debt': 1,
#  'Fine Arts': 33,
#  'Adobe Flash': 3,
#  'Action Script': 1,
#  'Trucking': 3,
#  'Bulk cargo': 1,
#  'Bulk Vessel Shipping': 1,
#  'Fabrics': 2,
#  'Textile': 7,
#  'Finished Garments': 1,
#  'Industrial': 13,
#  'Android Developer': 1,
#  'Sterilization': 1,
#  'Hygiene': 1,
#  'Sales Skils': 1,
#  'Business Management': 9,
#  'Sales B2B': 1,
#  'Site Management': 3,
#  'XML': 29,
#  'JSON': 34,
#  'SOAP': 12,
#  'XQuery': 1,
#  'Integration Development': 1,
#  'RDBMS': 2,
#  'HPLC': 2,
#  'Raw Materials': 4,
#  'Packaging Materials': 1,
#  'UV': 1,
#  'GC': 2,
#  'Oracle': 24,
#  'JVM': 1,
#  'Assistant': 6,
#  'Office Suite': 1,
#  'Negotiation Skills': 60,
#  'Android SDK': 5,
#  'Android Studio': 1,
#  'Low Current Systems': 6,
#  'Manager': 5,
#  'IS': 6,
#  'Less': 1,
#  'Servers': 3,
#  'Windows': 4,
#  'Virtualization': 3,
#  'Firewall': 2,
#  'System Administration': 20,
#  '30 Vacancies': 2,
#  'Data Labeling': 1,
#  'Remote': 1,
#  'ICU': 2,
#  'Social media marketing': 1,
#  'Facilities Management': 1,
#  'Content Marketing': 6,
#  'B2B': 32,
#  'Time Management': 5,
#  'Coaching': 3,
#  'Leads': 8,
#  'Information Technology(IT)': 1,
#  'Cloud Computing': 2,
#  'Presales': 8,
#  'Solution Architect': 1,
#  'Executive': 3,
#  'Contact Centers': 1,
#  'Outsourcing': 2,
#  'SQL Server': 5,
#  'Computing': 3,
#  'Programs': 1,
#  'HR Systems': 5,
#  'Employee Engagement': 2,
#  'Customer Focus': 6,
#  'Google Adwords': 27,
#  'Media Planning': 3,
#  'Media Strategy': 1,
#  'instagram': 1,
#  'Media': 30,
#  'Technology': 1,
#  'Copywriting': 12,
#  'Content Editing': 3,
#  'Communications': 18,
#  'content Creation': 1,
#  'KPI': 1,
#  'Design Patterns': 5,
#  'Laravel': 30,
#  'Vue Js': 1,
#  'Back-End': 11,
#  'Digital Sales': 2,
#  'Analytics': 3,
#  'Campaigns': 31,
#  'OD': 16,
#  'Fire Alarm': 12,
#  'NEC': 1,
#  'NFPA': 1,
#  'OSHA': 3,
#  'CCTV': 18,
#  'ERP Sales': 3,
#  'Household Appliances': 2,
#  'Showroom': 3,
#  'Home Appliances': 12,
#  'Operation': 4,
#  'AR': 15,
#  'Accounts Receivable': 19,
#  'Nursing': 3,
#  'Medical Marketing': 1,
#  'Medical Literature': 1,
#  'Corporate Finance': 2,
#  'Exterior Design': 1,
#  'Interior': 3,
#  'Sketchup': 3,
#  'Lumion': 2,
#  'Vray': 1,
#  'Training Cycle': 1,
#  'Training Specialist': 1,
#  'Training Coordinator': 1,
#  'Learning': 6,
#  'A+': 3,
#  'MS': 15,
#  'Surveying': 1,
#  'Mining Engineering': 1,
#  'Surveyor': 1,
#  'Site Architect': 1,
#  'Primavera': 15,
#  'Finishing': 8,
#  'Fit Out': 1,
#  'Odoo': 12,
#  'Business Processes': 3,
#  'Media Production': 1,
#  'Production Crew': 1,
#  'Cardiology': 3,
#  'MBBS': 1,
#  'Foreign Purchasing': 6,
#  'Shipping Documents': 1,
#  'Local Purchasing': 6,
#  'EMC': 1,
#  'J2EE': 6,
#  'Documentum': 1,
#  'IGC Brava': 1,
#  'Red Hat': 1,
#  'JDK': 1,
#  'WDK': 1,
#  'Webtop': 1,
#  'BPM': 3,
#  'DQL': 1,
#  'Property Sales': 20,
#  'Real Estate Team Leader': 1,
#  'Treasury': 9,
#  'Photographer': 1,
#  'Backend': 9,
#  'Oral Dentistry': 1,
#  'Dental Anatomy.': 1,
#  'Occlusion': 1,
#  'Prosthetic': 1,
#  'Dental Implantation': 1,
#  'Digital Dentistry': 2,
#  'Digital Smile Design': 1,
#  'Virtual Waxups': 1,
#  'SketchUp': 4,
#  'Illustrator': 17,
#  'Videographer': 3,
#  'Final Cut': 3,
#  'Digital Technology': 4,
#  'Videography': 8,
#  'Studio Lighting': 2,
#  'Editing Software Packages': 1,
#  'HR Diploma': 18,
#  'Organization Chart': 1,
#  'LV': 1,
#  'Regulatory Affairs': 3,
#  'CE': 2,
#  'FDA': 3,
#  'Water Treatment': 1,
#  'Art': 8,
#  'PMP': 30,
#  'Sciences': 5,
#  'Projects': 13,
#  'Budget Management': 1,
#  'Store Keeping': 15,
#  'Packing': 4,
#  'Packaging': 5,
#  'Social Media Channels': 3,
#  'Trados': 2,
#  'mysql': 1,
#  'Dentist': 4,
#  'MBA': 22,
#  'Informations Technology': 1,
#  'Branch Manager': 2,
#  'MCSA': 17,
#  'MCSE': 13,
#  'AR Accountant': 1,
#  'Problem Solving': 6,
#  'Immigration': 1,
#  'Financial Accountant': 2,
#  'Taxes': 6,
#  'Maya': 2,
#  'Art Direction': 1,
#  'Pumps': 6,
#  'Massive Hiring': 1,
#  'Offshore': 2,
#  'Government Units Relations': 1,
#  'Recruitment Agencies': 1,
#  'Schools': 1,
#  'Students Affairs': 1,
#  'Dental': 6,
#  'OSS': 1,
#  'SLCM': 1,
#  'IDOC': 1,
#  'ABAP HANA': 1,
#  'XL': 1,
#  'PY': 1,
#  'OM': 1,
#  'PA': 2,
#  'TM': 1,
#  'Bookkeeping': 7,
#  'Record-Keeping': 1,
#  'Veterinary': 18,
#  'Production Manager': 2,
#  'Agriculture Engineer': 1,
#  'Payroll': 32,
#  'Team Management': 2,
#  'Salary Adjustments': 1,
#  'Account Manager': 9,
#  'Agency': 4,
#  'BTL': 5,
#  'ATL': 3,
#  'brief': 1,
#  'presentations': 1,
#  'TTL': 1,
#  'Digital marketing': 1,
#  'Public Relations (PR)': 19,
#  'Brand Research': 1,
#  'Excel User': 1,
#  'Partnerships': 2,
#  'Deals': 2,
#  'Industry': 6,
#  'Performance': 4,
#  'Document Control': 6,
#  'EDMS': 1,
#  'Documents': 2,
#  'inventory': 1,
#  'ERP Systems': 4,
#  'Audit': 8,
#  'Budgeting': 12,
#  'Costing': 5,
#  'Financial Planning': 4,
#  'Presentation': 12,
#  'Inbound Marketing': 3,
#  'Outbound Marketing': 1,
#  'Network Administration': 9,
#  'File Management': 2,
#  'Contracting': 23,
#  'Contract Management': 1,
#  'client': 1,
#  'Twitter': 6,
#  'SaaS': 8,
#  'QC Lead': 1,
#  'SCCM': 2,
#  'WSUS': 2,
#  'SCOM': 2,
#  'STEP': 1,
#  'student': 1,
#  'technology': 2,
#  'software': 2,
#  '2021': 1,
#  'programming': 1,
#  'Sales Indoor': 2,
#  'Sales Outdoor': 1,
#  'Bancassurance Sales': 1,
#  'Microsoft Word': 27,
#  'Microsoft PowerPoint': 7,
#  'Banking': 32,
#  'Risk Management': 6,
#  'Microsoft Outlook': 3,
#  'Technical Lead': 1,
#  'Architect': 3,
#  'software development': 1,
#  'IBM InfoSphere DataStage': 1,
#  'Data Warehousing': 1,
#  'OLAP': 1,
#  'JDBC': 1,
#  'DB2 DBMS': 1,
#  'Chemical': 2,
#  'H2S': 1,
#  'Oil Refining': 1,
#  'Salesforce': 4,
#  'Business Intelligence': 5,
#  'BI': 5,
#  'Architectural Engineering': 8,
#  'Residential Projects': 3,
#  'Inventory Management': 6,
#  'Shipping': 21,
#  'Search Engine Optimization': 5,
#  'Website Analysis': 1,
#  'Compensation and Benefits': 2,
#  'Software Sales': 10,
#  'Business Deveopement': 1,
#  'BRD': 1,
#  'SRS': 3,
#  'Tax Management': 1,
#  'Tax Filing': 1,
#  'Configure': 2,
#  'ASM': 1,
#  'Solaris': 1,
#  'CentOS': 1,
#  'RedHat': 1,
#  'NGINX': 1,
#  'WHMCS': 1,
#  'Computer Engineeirng': 1,
#  'Cloud Engineering': 1,
#  'PaaS': 1,
#  'Operations Engineering': 1,
#  'UNIX': 2,
#  'MS Excel': 23,
#  'Graphic Designing': 4,
#  'DreamWeaver': 6,
#  'ISO9001': 1,
#  'ISO 17025': 1,
#  'ASTM E8': 1,
#  'ASTM E10': 1,
#  'Content Creator': 9,
#  'CTA': 3,
#  'Student activities': 1,
#  '· Administration': 1,
#  'Metal Markets': 1,
#  'Core': 2,
#  'Web': 10,
#  'Tax': 10,
#  'ERP System': 8,
#  'MOH': 1,
#  'Wet Utilities': 1,
#  'SWE': 2,
#  'Quantity Survey': 1,
#  'Technical Drawings': 4,
#  'ISO': 9,
#  'GL': 5,
#  'Accounts Payable': 17,
#  'AP': 9,
#  'Infrastructure': 7,
#  'Infrastracture': 1,
#  'Sewage Networks': 1,
#  'Sewer Cad': 1,
#  'SHRM-CP': 1,
#  'IT Administration': 1,
#  'Food Supply Chain': 1,
#  'Contract Specialist': 1,
#  'Tendring': 1,
#  'Tendering': 10,
#  ...}

# %%
sorted_skills= dict(sorted(skills_dic.items(), key= lambda item: item[1], reverse=True))

# %%
sorted_skills
# Out:
# {'English': 1269,
#  'Sales Skills': 776,
#  'Sales Target': 705,
#  'Computer Science': 690,
#  'Sales/Retail': 655,
#  'Microsoft Office': 580,
#  'Information Technology (IT)': 577,
#  'Customer Service': 573,
#  'Administration': 537,
#  'Communication Skills': 454,
#  'Software Development': 363,
#  'Customer Support': 347,
#  'Customer Care': 337,
#  'Accounting/Finance': 303,
#  'Finance': 300,
#  'Customer Service/Support': 287,
#  'Financial Analysis': 277,
#  'Marketing/PR/Advertising': 265,
#  'Social Media': 260,
#  'Business Development': 251,
#  'Engineering': 238,
#  'Communication': 235,
#  'Computer Skills': 233,
#  'Operations/Management': 215,
#  'Accounting': 208,
#  'Marketing': 206,
#  'Management': 194,
#  'Logistics': 191,
#  'IT/Software Development': 191,
#  'Creative/Design/Art': 186,
#  'Business Administration': 182,
#  'Office Management': 179,
#  'javaScript': 174,
#  'Financial Management': 174,
#  'Real Estate': 173,
#  'Logistics/Supply Chain': 167,
#  'E-marketing': 167,
#  'Supply Chain': 159,
#  'Arabic': 158,
#  'MS Office': 156,
#  'Digital Marketing': 154,
#  'Commerce': 154,
#  'Software Engineering': 152,
#  'Human Resources': 148,
#  'Computer Engineering': 147,
#  'Adobe Photoshop': 129,
#  'Quality': 127,
#  'Mechanical Engineering': 127,
#  'Media/Journalism/Publishing': 125,
#  'Design': 123,
#  'Engineering - Construction/Civil/Architecture': 121,
#  'Pharmaceutical': 120,
#  'Adobe Illustrator': 118,
#  'Recruitment': 118,
#  'Construction': 117,
#  'AutoCAD': 116,
#  'Project Management': 115,
#  'Education': 110,
#  'CSS': 109,
#  'Advertising': 109,
#  'Agile': 106,
#  'Education/Teaching': 105,
#  'HTML': 105,
#  'SEO': 104,
#  'Operations': 104,
#  'Secretary': 104,
#  'SQL': 103,
#  'Retail': 101,
#  'Males Only': 99,
#  'ERP': 99,
#  'Call Center': 97,
#  'Human Resources (HR)': 97,
#  'HR': 97,
#  'Medical/Healthcare': 96,
#  'Sales': 95,
#  'Engineering - Mechanical/Electrical': 95,
#  'Electrical Engineering': 93,
#  'Outdoor Sales': 90,
#  'Maintenance': 88,
#  'Excel': 85,
#  'Pharmacy': 83,
#  'Training': 82,
#  'Civil Engineering': 79,
#  'jQuery': 78,
#  'Medical': 78,
#  'HTML5': 78,
#  'Git': 76,
#  'Writing': 76,
#  'Manufacturing': 76,
#  'Personnel': 76,
#  'Telesales': 76,
#  'Architecture': 75,
#  'Graphic Design': 75,
#  'Procurement': 74,
#  'Market Research': 73,
#  'Science': 73,
#  'Installation': 73,
#  'Quality Assurance': 73,
#  'Quality Control': 72,
#  'Teaching': 71,
#  'IT': 71,
#  'Installation/Maintenance/Repair': 71,
#  'Business': 71,
#  'Negotiation': 70,
#  'PHP': 70,
#  'Microsoft Excel': 69,
#  'Writing/Editorial': 68,
#  'C#': 67,
#  'CRM': 66,
#  'MySQL': 66,
#  'UI': 65,
#  'Software': 65,
#  'R&D/Science': 65,
#  'Manufacturing/Production': 64,
#  'Females Only': 60,
#  'Negotiation Skills': 60,
#  'MVC': 58,
#  'Training/Instructor': 58,
#  'Purchasing': 58,
#  'Planning': 58,
#  'Creative': 57,
#  'FMCG': 56,
#  'Web Development': 55,
#  'CSS3': 55,
#  'Production': 54,
#  'Angular': 54,
#  'Leadership': 54,
#  'Online Marketing': 53,
#  'Engineering - Other': 51,
#  'QA': 51,
#  'SAP': 51,
#  'Programming': 51,
#  'Project/Program Management': 50,
#  'Fashion': 50,
#  'UX': 48,
#  'Indoor Sales': 48,
#  'Legal': 47,
#  'Purchasing/Procurement': 47,
#  'Technical Support': 47,
#  'Editing': 46,
#  'Insurance': 44,
#  'Presentation Skills': 43,
#  'ASP.NET': 42,
#  'Corporate Sales': 42,
#  '2 Vacancies': 42,
#  'Troubleshooting': 41,
#  'Java': 41,
#  'AWS': 40,
#  'Linux': 40,
#  'Google Analytics': 40,
#  'Account Management': 38,
#  'Content': 38,
#  'Property': 38,
#  'QC': 36,
#  'Photoshop': 35,
#  'Analyst/Research': 35,
#  'Healthcare': 35,
#  'OOP': 35,
#  'Startup': 35,
#  'Warehousing': 34,
#  'Engineering - Telecom/Technology': 34,
#  'JSON': 34,
#  'iOS': 33,
#  'Agriculture': 33,
#  'Fine Arts': 33,
#  'Software Testing': 32,
#  'Python': 32,
#  'B2B': 32,
#  'Payroll': 32,
#  'Banking': 32,
#  'Networking': 31,
#  'Males Preferred': 31,
#  'CCNA': 31,
#  'Auditing': 31,
#  'Analysis': 31,
#  'Campaigns': 31,
#  'Applied Arts': 30,
#  'Selling': 30,
#  'E-Commerce': 30,
#  'APIs': 30,
#  'Labor Law': 30,
#  'French': 30,
#  'Testing': 30,
#  'Media': 30,
#  'Laravel': 30,
#  'PMP': 30,
#  'Scrum': 29,
#  'Medicine': 29,
#  'XML': 29,
#  'Telecom': 28,
#  'Technical Office': 28,
#  'Front-End': 28,
#  'Research': 27,
#  'Android': 27,
#  'Brokerage': 27,
#  'Furniture': 27,
#  'Google Adwords': 27,
#  'Microsoft Word': 27,
#  'Revit': 27,
#  'React': 26,
#  '3D': 26,
#  'Accounting Software': 26,
#  'Telecommunication': 26,
#  'Business Analysis': 26,
#  'Inventory': 26,
#  'RESTful': 25,
#  '.NET': 25,
#  'SEM': 25,
#  'Interviewing': 25,
#  'Hiring': 25,
#  '3 Vacancies': 24,
#  'Interior Design': 24,
#  'Marketing Campaigns': 24,
#  'Females Preferred': 24,
#  'Web Design': 24,
#  'Oracle': 24,
#  'Electronics': 23,
#  'Real Estate Sales': 23,
#  'Digital Media': 23,
#  'Contracting': 23,
#  'MS Excel': 23,
#  'B2B Sales': 22,
#  'C++': 22,
#  'Facebook': 22,
#  'Mobile Development': 22,
#  'MBA': 22,
#  'Skills': 21,
#  'Content Writing': 21,
#  'Development': 21,
#  'Shipping': 21,
#  'Reporting': 21,
#  'CPA': 21,
#  'CMA': 21,
#  'AJAX': 20,
#  'Mechanical': 20,
#  'HVAC': 20,
#  'Security': 20,
#  'Bootstrap': 20,
#  'InDesign': 20,
#  'System Administration': 20,
#  'Property Sales': 20,
#  'Automotive': 20,
#  'TFS': 19,
#  'Receptionist': 19,
#  'Translation': 19,
#  'Adobe Indesign': 19,
#  'Help Desk': 19,
#  'Chemistry': 19,
#  'Content Creation': 19,
#  'Accounts Receivable': 19,
#  'Public Relations (PR)': 19,
#  'Screening': 19,
#  'WordPress': 18,
#  'Instructor': 18,
#  'Safety': 18,
#  'Branding': 18,
#  'Medical Sales': 18,
#  'Data Entry': 18,
#  'Communications': 18,
#  'CCTV': 18,
#  'HR Diploma': 18,
#  'Veterinary': 18,
#  'Front Office': 18,
#  'Selling Skills': 17,
#  'Sales Management': 17,
#  'E-commerce': 17,
#  'Export': 17,
#  'Sales Engineering': 17,
#  'JavaScript': 17,
#  'Illustrator': 17,
#  'MCSA': 17,
#  'Accounts Payable': 17,
#  'Swift': 17,
#  'Full Stack': 17,
#  'Distribution': 17,
#  'Information Technology': 17,
#  'RESTful APIs': 17,
#  'Repair': 16,
#  'Electrical': 16,
#  'MongoDB': 16,
#  'Telecom Engineering': 16,
#  'Hospitality': 16,
#  'Adobe After Effects': 16,
#  'OD': 16,
#  'REST': 16,
#  'Analytical': 16,
#  'Technical': 15,
#  'Front End': 15,
#  'DevOps': 15,
#  'Economics': 15,
#  'AR': 15,
#  'MS': 15,
#  'Primavera': 15,
#  'Store Keeping': 15,
#  'Collection': 15,
#  'Budget': 15,
#  'Mechatronics': 14,
#  'Azure': 14,
#  'R&D': 14,
#  'Video Editing': 14,
#  'Jira': 14,
#  'Travel': 14,
#  'Content Management': 14,
#  'Sourcing': 14,
#  'Lighting': 14,
#  'Accountant': 14,
#  'Product Management': 13,
#  '3D Max': 13,
#  'Other': 13,
#  '3ds Max': 13,
#  'Docker': 13,
#  'Lead Generation': 13,
#  'React Native': 13,
#  'Data Analysis': 13,
#  'Cost Accounting': 13,
#  'Networks': 13,
#  'SASS': 13,
#  'Industrial': 13,
#  'Projects': 13,
#  'MCSE': 13,
#  'Talent Acquisition': 13,
#  '2D': 13,
#  'Hardware': 13,
#  'CAD': 12,
#  'Cloud': 12,
#  'After Effects': 12,
#  'IT Sales': 12,
#  'Online Sales': 12,
#  'UI/UX': 12,
#  'Adobe Premiere': 12,
#  'SOAP': 12,
#  'Copywriting': 12,
#  'Fire Alarm': 12,
#  'Home Appliances': 12,
#  'Odoo': 12,
#  'Budgeting': 12,
#  'Presentation': 12,
#  'PR': 12,
#  'Localization': 12,
#  '10 Vacancies': 12,
#  'Cisco': 12,
#  'Tourism': 12,
#  'Customer Services': 12,
#  'Photography': 11,
#  'Admin Assistant': 11,
#  'Computer': 11,
#  'PPC': 11,
#  'Google Ads': 11,
#  'Import': 11,
#  'Supply Chain Management': 11,
#  'Civil': 11,
#  'Word': 11,
#  'Performance Management': 11,
#  'Microsoft SQL Server': 11,
#  'Property Consultant': 11,
#  'SharePoint': 11,
#  'Database': 11,
#  'Administrative': 11,
#  'Back-End': 11,
#  'Law': 11,
#  'MVVM': 11,
#  'Node.js': 11,
#  'Flutter': 11,
#  'Automation': 11,
#  'Redux': 11,
#  'Access Control': 11,
#  'Food': 11,
#  'Sales Accounting': 11,
#  'CCNP': 10,
#  'Six Sigma': 10,
#  'Product': 10,
#  'System Analysis': 10,
#  'Implementation': 10,
#  'Warehouse': 10,
#  'Admin Work': 10,
#  'Employee Relations': 10,
#  'Shop Drawings': 10,
#  'Site': 10,
#  'Front Desk': 10,
#  'Media Buying': 10,
#  'API': 10,
#  'Food Industry': 10,
#  'Software Sales': 10,
#  'Web': 10,
#  'Tax': 10,
#  'Tendering': 10,
#  'Telemarketing': 10,
#  'TEFL': 10,
#  'GIT': 10,
#  'Journalism': 10,
#  'Graphics': 10,
#  'Store Management': 10,
#  'International School': 10,
#  'Mathematics': 10,
#  '5 Vacancies': 10,
#  '4 Vacancies': 10,
#  'Computer Hardware': 10,
#  'Adobe Creative Suite': 9,
#  'SolidWorks': 9,
#  'ISTQB': 9,
#  'MEP': 9,
#  'Site Engineering': 9,
#  'Typing': 9,
#  'AngularJS': 9,
#  'Business Management': 9,
#  'Treasury': 9,
#  'Backend': 9,
#  'Account Manager': 9,
#  'Network Administration': 9,
#  'Content Creator': 9,
#  'ISO': 9,
#  'AP': 9,
#  'CMS': 9,
#  'Animation': 9,
#  'TO': 9,
#  'Family Palnning': 9,
#  'Contraceptives': 9,
#  'MoHP': 9,
#  'Customer Relations': 9,
#  'Commercial': 9,
#  'Agricultural Engineering': 9,
#  'Technical Sales': 9,
#  'Primary': 9,
#  'NodeJS': 9,
#  'Financial Reporting': 9,
#  'Cosmetics': 9,
#  'English Teaching': 8,
#  'Inventory Control': 8,
#  'Production Engineering': 8,
#  'Digital': 8,
#  'DNS': 8,
#  'Motion Graphics': 8,
#  'GAAP': 8,
#  'Leads': 8,
#  'Presales': 8,
#  'Finishing': 8,
#  'Videography': 8,
#  'Art': 8,
#  'Audit': 8,
#  'SaaS': 8,
#  'Architectural Engineering': 8,
#  'ERP System': 8,
#  'Brokerage Real Estate': 8,
#  'Graphic Designer': 8,
#  'Social Media Marketing': 8,
#  'Light Current': 8,
#  'Hotels': 8,
#  'Branch Management': 8,
#  'General Ledger': 8,
#  'Stock Control': 8,
#  'PostgreSQL': 8,
#  'Configuration': 8,
#  'Sales Admin': 8,
#  'German': 8,
#  'JQuery': 8,
#  'Contracts': 8,
#  'HSE': 8,
#  '1-3 Yrs of Exp': 8,
#  'VMWare': 8,
#  'Sketch': 8,
#  'Merchandising': 8,
#  'NoSQL': 8,
#  'Cost Control': 8,
#  'Architecture Engineering': 8,
#  'Publishing': 7,
#  'Selecting': 7,
#  'Selenium': 7,
#  'Printing': 7,
#  'Project Coordination': 7,
#  'Vet': 7,
#  'ROI': 7,
#  'Mobile Applications': 7,
#  'Jenkins': 7,
#  'Mobile Application': 7,
#  'Hospitality/Hotels/Food Services': 7,
#  'Auto CAD': 7,
#  'Drawing': 7,
#  'AX': 7,
#  'Web API': 7,
#  'Back End': 7,
#  'Adobe Suite': 7,
#  'Documentation': 7,
#  'Internal Audit': 7,
#  'Textile': 7,
#  'Bookkeeping': 7,
#  'Microsoft PowerPoint': 7,
#  'Infrastructure': 7,
#  'Resale': 7,
#  'Objective-C': 7,
#  'Linguistics': 7,
#  'Site Engineer': 7,
#  'Computer Maintenance': 7,
#  'BMS': 7,
#  'People Management': 7,
#  'Adobe XD': 7,
#  'Executive Secretary': 7,
#  'E-Learning': 7,
#  'Freight Forwarding': 7,
#  'Food & Beverage': 7,
#  'School': 7,
#  'IFRS': 7,
#  'Tourism/Travel': 7,
#  'Wireframes': 7,
#  'WAN': 7,
#  '1+ Yrs of Exp': 7,
#  'Instructing': 7,
#  'Telecommunications': 7,
#  'Spare Parts': 7,
#  'JS': 7,
#  'Events': 7,
#  'Reception': 7,
#  'Account Managment': 7,
#  'Marketing Management': 6,
#  'Admin': 6,
#  'Languages': 6,
#  'Teacher': 6,
#  'Instagram': 6,
#  'Wood': 6,
#  'Sports and Leisure': 6,
#  'Dentistry': 6,
#  'Creativity': 6,
#  'GraphQL': 6,
#  'Factory': 6,
#  'Electrical Power': 6,
#  'Leadership Skills': 6,
#  'Sales Executive': 6,
#  'Financial Reports': 6,
#  'Cost': 6,
#  'HRIS': 6,
#  'Financial Statements': 6,
#  'Assistant': 6,
#  'Low Current Systems': 6,
#  'IS': 6,
#  'Content Marketing': 6,
#  'Customer Focus': 6,
#  'Learning': 6,
#  'Foreign Purchasing': 6,
#  'Local Purchasing': 6,
#  'J2EE': 6,
#  'Problem Solving': 6,
#  'Taxes': 6,
#  'Pumps': 6,
#  'Dental': 6,
#  'Industry': 6,
#  'Document Control': 6,
#  'Twitter': 6,
#  'Risk Management': 6,
#  'Inventory Management': 6,
#  'DreamWeaver': 6,
#  'Project Manager': 6,
#  'Vendor Management': 6,
#  'HR Certificate': 6,
#  'Business Planning': 6,
#  'Public Relations': 6,
#  'Entity Framework': 6,
#  'Strategic Planning': 6,
#  'Odoo ERP': 6,
#  'Warehouse Management': 6,
#  'Power BI': 6,
#  'Spring': 6,
#  'Digital Education': 6,
#  'Sales Buzz': 6,
#  'Fire Fighting': 6,
#  'Health & Safety': 6,
#  'Chemicals': 6,
#  'Typescript': 6,
#  'Blue Collars': 6,
#  'LAN': 6,
#  'Spring Boot': 6,
#  'Delivery': 6,
#  'Sales Plan': 6,
#  'Agriculture Engineering': 6,
#  'Veterinary Medicine': 6,
#  'Java EE': 6,
#  'Taxation': 6,
#  'PowerPoint': 6,
#  'Storekeeping': 5,
#  'Copywriter': 5,
#  'Microsoft': 5,
#  'Automation Testing': 5,
#  'Back Office': 5,
#  'Strategy': 5,
#  'UI Design': 5,
#  'Kubernetes': 5,
#  'Biomedical Engineering': 5,
#  'Writing Skills': 5,
#  'Microsoft Dynamics AX': 5,
#  'Microsoft Dynamics': 5,
#  'Visio': 5,
#  'Technical Writing': 5,
#  'MRP': 5,
#  'HR Management': 5,
#  'Marketing Strategy': 5,
#  'CFA': 5,
#  'Android SDK': 5,
#  'Manager': 5,
#  'Time Management': 5,
#  'SQL Server': 5,
#  'HR Systems': 5,
#  'Design Patterns': 5,
#  'Sciences': 5,
#  'Packaging': 5,
#  'BTL': 5,
#  'Costing': 5,
#  'Business Intelligence': 5,
#  'BI': 5,
#  'Search Engine Optimization': 5,
#  'GL': 5,
#  'Active Directory': 5,
#  'PowerShell': 5,
#  '8 Vacancies': 5,
#  'Kotlin': 5,
#  'React.js': 5,
#  'GitHub': 5,
#  'MSSQL': 5,
#  'Air Conditioning': 5,
#  'Power': 5,
#  'Information Systems': 5,
#  'Social Networking': 5,
#  'Configuring': 5,
#  'Web Applications': 5,
#  'ReactJS': 5,
#  'WCF': 5,
#  'Appium': 5,
#  'Nodejs': 5,
#  'Product Owner': 5,
#  'SVN': 5,
#  'HACCP': 5,
#  'Communication Engineering': 5,
#  'Operations Management': 5,
#  'Network': 5,
#  'F&B': 5,
#  'Retail Sales': 5,
#  'Statistics': 5,
#  'TDD': 5,
#  'ITI': 5,
#  'CPIM': 5,
#  'Residential': 5,
#  'Poultry': 5,
#  'Chemical Engineering': 5,
#  'InVision': 5,
#  'Farming': 5,
#  'LESS': 5,
#  'Computer Systems': 5,
#  'Consulting': 5,
#  'Personal Assistant': 5,
#  'Customer Satisfaction': 5,
#  'Sales Strategy': 5,
#  'ICDL': 5,
#  'White Collars': 5,
#  'Export Sales': 5,
#  'Painting': 5,
#  'Plumbing': 5,
#  'Woods': 5,
#  'Building Material': 5,
#  'Design Software': 4,
#  'Industrial Engineering': 4,
#  'Sales Manager': 4,
#  'Coding': 4,
#  'Editorial': 4,
#  'Youtube': 4,
#  'CI/CD': 4,
#  'Apache': 4,
#  'Furniture Sales': 4,
#  'Odoo Modules': 4,
#  'Sports': 4,
#  'Maths': 4,
#  'Tomcat': 4,
#  'After Effect': 4,
#  'Research & Development': 4,
#  'Fleet Management': 4,
#  'Power Engineering': 4,
#  'Technical Analysis': 4,
#  'Social Media Management': 4,
#  'SSRS': 4,
#  'Compensation': 4,
#  'Organizational Development': 4,
#  'Architectural': 4,
#  'Product Development': 4,
#  'Analyst': 4,
#  'Production Planning': 4,
#  'Facebook Ads': 4,
#  'Vendors': 4,
#  'Raw Materials': 4,
#  'Windows': 4,
#  'Operation': 4,
#  'SketchUp': 4,
#  'Digital Technology': 4,
#  'Packing': 4,
#  'Dentist': 4,
#  'Agency': 4,
#  'Performance': 4,
#  'ERP Systems': 4,
#  'Financial Planning': 4,
#  'Salesforce': 4,
#  'Graphic Designing': 4,
#  'Technical Drawings': 4,
#  'TESOL': 4,
#  'BIM': 4,
#  'Biotechnology': 4,
#  'UPS': 4,
#  'Data Center': 4,
#  'CI': 4,
#  'System Engineering': 4,
#  'Xamarin': 4,
#  'Ionic': 4,
#  'UX Design': 4,
#  'Frameworks': 4,
#  'Compliance': 4,
#  'Figma': 4,
#  'Integration': 4,
#  'MS-SQL': 4,
#  'BOQ': 4,
#  'Bitbucket': 4,
#  'CDS': 4,
#  'Transportation': 4,
#  'Shipments': 4,
#  'CIMA': 4,
#  'Animal Production': 4,
#  'Material': 4,
#  'Hospital': 4,
#  'Medical Insurance': 4,
#  'MS Project': 4,
#  'Pricing': 4,
#  'Premiere Pro': 4,
#  'General Accounting': 4,
#  'MYSQL': 4,
#  'Firewalls': 4,
#  'Network Security': 4,
#  'Trainer': 4,
#  'CRM Software': 4,
#  'Tax Accounting': 4,
#  'Cost Estimation': 4,
#  'CNC': 4,
#  'Relationship Management': 4,
#  'Colors': 4,
#  'Hibernate': 4,
#  'Pharmaceutical Sciences': 4,
#  'XD': 4,
#  'App Store': 4,
#  'Fitness': 4,
#  'Marketing Campaign': 4,
#  'Recruiting': 4,
#  'Consultancy': 4,
#  'Medical Devices': 4,
#  'Fleet': 4,
#  'C#.Net': 4,
#  'Coordination': 4,
#  'Analytical Skills': 4,
#  'QuickBooks': 4,
#  'Proofreading': 4,
#  'Customer Complaints': 4,
#  'Client Relationships': 4,
#  'CELTA': 4,
#  'Audio Visual': 4,
#  'Quantity Surveying': 4,
#  'Control': 4,
#  'Sales Support': 4,
#  'Aluminum': 4,
#  'Web Services': 4,
#  '3+ Yrs of Exp': 4,
#  'Objective C': 4,
#  'Sales Operations': 4,
#  'Internal Auditing': 4,
#  'Facility Management': 4,
#  'Nursery': 4,
#  'ETL': 4,
#  'Strategy/Consulting': 4,
#  'Data Warehouse': 4,
#  'Shopify': 4,
#  'Brand Management': 4,
#  'Technical Office Engineer': 4,
#  'Kanban': 4,
#  'Java SE': 4,
#  'Code Versioning Tools': 4,
#  'Fundraising': 4,
#  'Pipes': 4,
#  'Javascript': 4,
#  'Express': 4,
#  'Low Voltage': 4,
#  'Finishing Works': 4,
#  'Drawings': 4,
#  '2+ Yrs of Exp': 4,
#  'Pre-Sales': 4,
#  'Real Estate Development': 4,
#  'Social Studies': 4,
#  'Information Security': 4,
#  'Electromechanical': 4,
#  'B2C': 4,
#  'SCM': 4,
#  'AutoCAD 2D': 4,
#  'Driving ID': 4,
#  'Driving Licences': 4,
#  'Car': 4,
#  'Marketing Plan': 3,
#  'MS SQL': 3,
#  'sales skills': 3,
#  'Labor': 3,
#  'Video Production': 3,
#  'Mechanical Design': 3,
#  'Interviews': 3,
#  'Mass Hiring': 3,
#  'Hotel': 3,
#  'Health': 3,
#  'Lab': 3,
#  'Sales Supervisor': 3,
#  'Biology': 3,
#  'Physics': 3,
#  'Supervisor': 3,
#  'engineering': 3,
#  'google': 3,
#  'java': 3,
#  'T-SQL': 3,
#  'UI/UX Design': 3,
#  'Gym': 3,
#  'DHCP': 3,
#  'Typing Skills': 3,
#  'Material Planning': 3,
#  'Suppliers': 3,
#  'Doctor': 3,
#  'C-Level Executive/GM/Director': 3,
#  'Office Furniture': 3,
#  'Heavy Equipment': 3,
#  'Dutch': 3,
#  'Team Leader': 3,
#  'Financial': 3,
#  'Node.JS': 3,
#  'Android Development': 3,
#  'Instructional Design': 3,
#  'Social Media Campaigns': 3,
#  'Data Mining': 3,
#  'Health and Safety': 3,
#  'Editing Software': 3,
#  'SCSS': 3,
#  'REST APIs': 3,
#  'Adobe Flash': 3,
#  'Trucking': 3,
#  'Site Management': 3,
#  'Servers': 3,
#  'Virtualization': 3,
#  'Coaching': 3,
#  'Executive': 3,
#  'Computing': 3,
#  'Media Planning': 3,
#  'Content Editing': 3,
#  'Analytics': 3,
#  'OSHA': 3,
#  'ERP Sales': 3,
#  'Showroom': 3,
#  'Nursing': 3,
#  'Interior': 3,
#  'Sketchup': 3,
#  'A+': 3,
#  'Business Processes': 3,
#  'Cardiology': 3,
#  'BPM': 3,
#  'Videographer': 3,
#  'Final Cut': 3,
#  'Regulatory Affairs': 3,
#  'FDA': 3,
#  'Social Media Channels': 3,
#  'ATL': 3,
#  'Inbound Marketing': 3,
#  'Microsoft Outlook': 3,
#  'Architect': 3,
#  'Residential Projects': 3,
#  'SRS': 3,
#  'CTA': 3,
#  'Document Controller': 3,
#  'Medical Sales Representative': 3,
#  'Structural': 3,
#  'English Literature': 3,
#  'Cashier': 3,
#  'POS': 3,
#  'Broker': 3,
#  'Office Automation': 3,
#  'HRMS': 3,
#  'SDK': 3,
#  'Sales Account Management': 3,
#  'Database Administration': 3,
#  '.NET Core': 3,
#  'Plant Management': 3,
#  'Sketch-up': 3,
#  'Office Administration': 3,
#  'Visual Arts': 3,
#  'QS': 3,
#  'Shop Drawing': 3,
#  '2-10 Yrs of Exp': 3,
#  'Mental Health': 3,
#  'Office Manager': 3,
#  'Ecommerce': 3,
#  'Hospitals': 3,
#  'Engineering - Oil & Gas/Energy': 3,
#  'Marketing Strategies': 3,
#  'Routing': 3,
#  'Food and Beverage': 3,
#  'Frontend': 3,
#  'Snapchat': 3,
#  'Customer Relationship': 3,
#  'Product Design': 3,
#  '3D Modeling': 3,
#  'Software Quality': 3,
#  'Mobile Apps': 3,
#  'Github': 3,
#  'Firebase': 3,
#  'Billing': 3,
#  'MS Power Platform': 3,
#  'MS Cloud Services': 3,
#  'Data Management': 3,
#  'Ticketing': 3,
#  'Accounting Principles': 3,
#  'Courier': 3,
#  'ACCA': 3,
#  'Talent Management': 3,
#  'Advertising Campaigns': 3,
#  'Reports': 3,
#  'ITIL': 3,
#  'SDLC': 3,
#  'logistics': 3,
#  'Ms Office': 3,
#  'Recruiter': 3,
#  'Filmmaking': 3,
#  'ES6': 3,
#  'Ledgers': 3,
#  'Fixed Assets': 3,
#  'CAPA': 3,
#  'GMP': 3,
#  'Sales Coordinator': 3,
#  'Sales Engineer': 3,
#  'Adobe': 3,
#  'Backup': 3,
#  'Plastic': 3,
#  'Microbiology': 3,
#  'Laboratory': 3,
#  'MVP': 3,
#  'Django': 3,
#  'Human Resources Management': 3,
#  'Sales Representative': 3,
#  'Market Analysis': 3,
#  'Trading': 3,
#  'Utilities': 3,
#  'Windows Server': 3,
#  'Sales Strategies': 3,
#  'Raw Material': 3,
#  'ADF': 3,
#  'Lean Warehouse': 3,
#  'Trends': 3,
#  'User Interface': 3,
#  'Professional Teaching Certificate': 3,
#  'Biochemistry': 3,
#  'Data Analytics': 3,
#  'CSCP': 3,
#  'Support': 3,
#  'Orders': 3,
#  'Oil & Gas': 3,
#  'Adobe Creative Cloud': 3,
#  'Biomedical': 3,
#  'ADO.NET': 3,
#  'Farms': 3,
#  'COPC': 3,
#  'Angular JS': 3,
#  'Axure': 3,
#  'Prototyping': 3,
#  'Copy Writing': 3,
#  'Customer Experience': 3,
#  'Modern Trade': 3,
#  'BDD': 3,
#  'FELT': 3,
#  'ISO 9001': 3,
#  'Computer Software': 3,
#  'null Yrs of Exp': 3,
#  'E-Marketing': 3,
#  'Core Data': 3,
#  'Facade': 3,
#  'Oracle SOA': 3,
#  'Switching': 3,
#  'NEBOSH': 3,
#  'Premiere': 3,
#  'code': 3,
#  'Assistance': 3,
#  'TypeScript': 3,
#  'Employment': 3,
#  'Sheet Metal': 3,
#  'Online Media': 3,
#  'Emails': 3,
#  'Food And Beverage': 3,
#  'ESL': 3,
#  'Cross Platform': 3,
#  'Social Insurance': 3,
#  'Dairy': 3,
#  'Electronics Engineering': 3,
#  'Data Science': 3,
#  'Cold Calling': 3,
#  'Digital Content': 3,
#  'Paints': 3,
#  'Performance Appraisal': 3,
#  'Clinical Research': 3,
#  'Selection': 3,
#  'Acrobat': 3,
#  '.Net': 3,
#  ...}

# %%
# 2nd way 
dataframe1=pd.DataFrame(skills, columns=['skills'])
dataframe1["skills"].value_counts()
# Out:
# English             1269
# Sales Skills         776
# Sales Target         705
# Computer Science     690
# Sales/Retail         655
#                     ...
# Child Education        1
# XL                     1
# Rent                   1
# Lower Primar           1
# Medical Supplies       1
# Name: skills, Length: 3985, dtype: int64
